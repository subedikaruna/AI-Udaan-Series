# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
bp1=pd.DataFrame({
"Employee_Name": ["Ramesh", "Amesh", "Mesh", "Esh", "Sh", "H", "Anish", "Nish"],
"Salary":[1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000]
})
plt.boxplot(bp1["Salary"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29391d48550>,
#   <matplotlib.lines.Line2D at 0x29391d48690>],
#  'caps': [<matplotlib.lines.Line2D at 0x29391d487d0>,
#   <matplotlib.lines.Line2D at 0x29391d48910>],
#  'boxes': [<matplotlib.lines.Line2D at 0x29391d48410>],
#  'medians': [<matplotlib.lines.Line2D at 0x29391d48a50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x29391d48b90>],
#  'means': []}

# %%
bp2=pd.DataFrame({
"Employee_Name": ["Ramesh", "Amesh", "Mesh", "Esh", "Sh", "H", "Anish", "Nish","Outlier"],
"Salary":[1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000,50000]
})
plt.boxplot(bp2["Salary"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29391db4550>,
#   <matplotlib.lines.Line2D at 0x29391db4690>],
#  'caps': [<matplotlib.lines.Line2D at 0x29391db47d0>,
#   <matplotlib.lines.Line2D at 0x29391db4910>],
#  'boxes': [<matplotlib.lines.Line2D at 0x29391db4410>],
#  'medians': [<matplotlib.lines.Line2D at 0x29391db4a50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x29391db4b90>],
#  'means': []}

# %%
bp3=pd.read_csv("datasets/daraz_dataset.csv")
plt.boxplot(bp3["TotalAmount"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29391f3a350>,
#   <matplotlib.lines.Line2D at 0x29391f3a490>],
#  'caps': [<matplotlib.lines.Line2D at 0x29391f3a5d0>,
#   <matplotlib.lines.Line2D at 0x29391f3a710>],
#  'boxes': [<matplotlib.lines.Line2D at 0x29391f3a210>],
#  'medians': [<matplotlib.lines.Line2D at 0x29391f3a850>],
#  'fliers': [<matplotlib.lines.Line2D at 0x29391f3a990>],
#  'means': []}
